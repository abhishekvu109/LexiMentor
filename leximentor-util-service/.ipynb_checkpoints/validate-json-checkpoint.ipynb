# %%
import json
import re

raw_json = '''{\n  \"errorList\": [\n    {\n      \"id\": \"err-1\",\n      \"type\": \"Grammar\",\n      \"subType\": \"Subject-Verb Agreement\",\n      \"incorrectText\": \"has shown an increase in political engagement, but it also has its pitfalls.\",\n      \"correctedText\": \"Has shown an increase in political engagement, but it also presents several challenges.\",\n      \"explanation\": \"The verb 'has' should agree with the subject 'political discourse,' which is singular. Using 'it' as an impersonal pronoun may not always be necessary.\"\n    },\n    {\n      \"id\": \"err-2\",\n      \"type\": \"Grammar\",\n      \"subType\": \"Article Usage\",\n      \"incorrectText\": \"With the rise of platforms like Twitter, Facebook, and Instagram, political discourse is no longer limited to leaders or experts—everyone can now participate.\",\n      \"correctedText\": \"With the rise of platforms like Twitter, Facebook, and Instagram, political discourse is no longer limited to leaders or experts; everyone can now participate.\",\n      \"explanation\": \"An em dash should be used instead of an en dash after 'experts.'\"\n    },\n    {\n      \"id\": \"err-3\",\n      \"type\": \"Grammar\",\n      \"subType\": \"Passive Voice\",\n      \"incorrectText\": \"This accessibility has increased political engagement, but it also raised the risk of misinformation spreading rapidly.\",\n      \"correctedText\": \"Greater access to information and platforms has enabled more people to engage politically while simultaneously increasing the spread of potential misinformation.\",\n      \"explanation\": \"The sentence uses passive voice unnecessarily. Active verbs are preferred for clarity and conciseness.\"\n    },\n    {\n      \"id\": \"err-4\",\n      \"type\": \"Vocabulary\",\n      \"subType\": \"Precision\",\n      \"incorrectText\": \"Many users don’t verify facts before sharing a post—they believe it because it matches their opinion or was shared by someone they trust.\",\n      \"correctedText\": \"Many individuals fail to fact-check information before sharing posts, often accepting content as true because it aligns with their preconceptions or is circulated by trusted sources.\",\n      \"explanation\": \"The phrase 'don’t verify facts' is more concise and precise than the original.\"\n    },\n    {\n      \"id\": \"err-5\",\n      \"type\": \"Vocabulary\",\n      \"subType\": \"Clarity\",\n      \"incorrectText\": \"This removes the traditional gatekeepers like news channels and allows leaders to explain policies, share updates, or respond to citizens.\",\n      \"correctedText\": \"Direct communication from political figures via social media bypasses traditional news channels and allows leaders to disseminate policies, updates, or respond to the public.\",\n      \"explanation\": \"The sentence is clearer when rephrased for better flow.\"\n    },\n    {\n      \"id\": \"err-6\",\n      \"type\": \"Grammar\",\n      \"subType\": \"Contraction Usage\",\n      \"incorrectText\": \"If used to spread hate or false information, the impact can be harmful.\",\n      \"correctedText\": \"If leaders use these platforms irresponsibly to propagate hatred or misinformation, it becomes detrimental.\"\n      ,\n      \"explanation\": \"'Don’t\" },{\"id\":\"err-7\",\"type\":\"Grammar\",\"subType\":\"Tense\",\"incorrectText\":\"social media has become one of the most important parts of people's lives.\",\"correctedText\":\"Social media is now considered a crucial component of modern life.\",\"explanation\": \"'Has' should be replaced with 'is' to maintain consistency in the present tense. Also, use more formal language for academic tone.\"},{\"id\":\"err-8\",\"type\":\"Punctuation\",\"subType\":\"Comma Splice\",\"incorrectText\":\"Many news outlets now prioritize content that gets more likes and shares, sometimes at the expense of accuracy.\",\"correctedText\":\"However, many news organizations increasingly emphasize engagement metrics like likes and shares over rigorous fact-checking.\",\"explanation\": \"The comma splice should be corrected to improve readability. Also, the phrase 'sometimes at the expense of accuracy' could use a semicolon for better flow.\"},{\"id\":\"err-9\",\"type\":\"Grammar\",\"subType\":\"Clause Agreement\",\"incorrectText\":\"The rise of fake news and online harassment often discourages individuals from expressing their views.\",\"correctedText\":\"Additionally, the spread of fake news and instances of online harassment can discourage people from openly discussing political matters.\",\"explanation\": \"'Often discourages' should be 'often discourage to deter individuals'\"},{\"id\":\"err-10\",\"type\":\"Grammar\",\"subType\":\"Article Usage\",\"incorrectText\":\"social media platforms use algorithms that show users content based on their past behavior.\",\"correctedText\":\"Social media companies utilize algorithmic filtering to tailor user feeds according to historical engagement patterns.\",\"explanation\": \"Use 'algorithm' instead of the more technical term for clarity. Also, use a semicolon after 'However,' for better structure.\"},{\"id\":\"err-11\",\"type\":\"Grammar\",\"subType\":\"Verb Form\",\"incorrectText\":\"social media has made it very easy for everyone to share their opinions, now political discourse is no longer limited.\",\"correctedText\":\"Social media platforms have simplified the process of sharing personal viewpoints, thereby expanding participation in political discussions.\",\"explanation\": \"'Has' should be replaced with 'have.' Also, use a semicolon to connect independent clauses. Remove redundancy by rephrasing the second clause.\"},{\"id\":\"err-12\",\"type\":\"Grammar\",\"subType\":\"Article Usage\",\"incorrectText\":\"While this shift has brought some benefits, it also created several problems in how people discuss and understand politics.\",\"correctedText\":\"This transformation of political discourse has introduced both advantages—such as increased engagement—and challenges, including the rapid spread of misinformation.\",\"explanation\": \"Use a comma after 'While' and remove redundancy by rephrasing to avoid repetition. Also use more formal language for academic tone.\"},{\"id\":\"err-13\",\"type\":\"Grammar\",\"subType\":\"Tense Transition\",\"incorrectText\":\"During elections, this becomes especially dangerous, as fake news can influence how people vote or view a candidate.\",\"correctedText\":\"Especially during election periods, the unchecked spread of misinformation poses risks to voting behaviors and public perceptions of candidates.\",\"explanation\": \"'Becomes' should be replaced with 'become' for parallel structure. Also, use a comma after 'During elections.' Remove redundancy by rephrasing to clarify the connection between fake news and voting.\"},{\"id\":\"err-14\",\"type\":\"Grammar\",\"subType\":\"Article Usage\",\"incorrectText\":\"Several recent elections around the world have shown the harmful effects of misinformation.\",\"correctedText\":\"Recent global election cycles have demonstrated how unchecked misinformation can distort democratic processes.\",\"explanation\": \"Use a semicolon after 'However,' to connect independent clauses. Remove redundancy by rephrasing the sentence for conciseness and clarity.\"},{\"id\":\"err-15\",\"type\":\"Grammar\",\"subType\":\"Subject-Verb Agreement\",\"incorrectText\":\"social media has become a major tool for communication and information dissemination.\",\"correctedText\":\"Social media serves as both an effective medium of personal interaction and public discourse.\",\"explanation\": \"Use a more formal structure to convey the message clearly. Remove redundancy by rephrasing for conciseness.\"},{\"id\":\"err-16\",\"type\":\"Punctuation\",\"subType\":\"Quotation Marks\",\"incorrectText\":\"social media has become one of the most important parts of people's lives.\",\"correctedText\":\"Social media, as a critical component of modern communication and information exchange.\",\"explanation\": \"Remove quotation marks since the statement is not being quoted. Use semicolon for better flow after 'However.'\"},{\"id\":\"err-17\",\"type\":\"Punctuation\",\"subType\":\"Missing Apostrophe\",\"incorrectText\":\"Many individuals fail to fact-check information before sharing posts, often accepting content as true because it matches their preconceptions or is circulated by trusted sources.\",\"correctedText\":\"Many individuals fail to fact-check information before sharing posts, often accepting content as true because it aligns with their preconceptions or is disseminated by trusted sources.\",\"explanation\": \"The original text already has the correct apostrophe. No change needed here.\"},{\"id\":\"err-18\",\"type\":\"Punctuation\",\"subType\":\"Comma Usage\",\"incorrectText\":\"However, many news organizations increasingly emphasize engagement metrics like likes and shares over rigorous fact-checking.\",\"correctedText\":\"However, many news outlets now prioritize user-engagement metrics such as likes and shares at the expense of thorough investigative reporting.\",\"explanation\": \"Use a semicolon after 'However,' to improve sentence structure. Remove redundancy by rephrasing for conciseness and clarity.\"},{\"id\":\"err-19\",\"type\":\"Grammar\",\"subType\":\"Clause Agreement\",\"incorrectText\":\"social media has transformed political discourse in significant ways, making it more open and participatory but also more polarized and emotionally charged.\",\"correctedText\":\"Social media's impact on politics is twofold: while democratizing participation, it simultaneously amplifies polarization and emotional responses.\",\"explanation\": \"'Has' should be replaced with 'has in terms of.' Use a semicolon after the first clause to improve clarity. Remove redundancy by rephrasing for conciseness.\"},{\"id\":\"err-20\",\"type\":\"Grammar\",\"subType\":\"Article Usage\",\"incorrectText\":\"social media has transformed political discourse in significant ways, making it more open and participatory but also more polarized and emotionally charged.\",\"correctedText\":\"Social media's influence on politics is evident as political discourse becomes both democratized in participation yet increasingly divisive.\",\"explanation\": \"Use a semicolon after 'evident' to connect independent clauses. Remove redundancy by rephrasing for conciseness and clarity.\"},{\"id\":\"err-21\",\"type\":\"Grammar\",\"subType\":\"Passive Voice\",\"incorrectText\":\"social media has transformed political discourse in significant ways, making it more open and participatory but also more polarized and emotionally charged.\",\"correctedText\":\"Social media's influence on politics is evident as political discourse becomes both democratized in participation yet simultaneously amplified in polarization.\",\"explanation\": \"Use active voice where possible. Remove redundancy by rephrasing for conciseness and clarity.\"},{\"id\":\"err-22\",\"type\":\"Grammar\",\"subType\":\"Clause Agreement\",\"incorrectText\":\"social media has transformed political discourse in significant ways, making it more open and participatory but also more polarized and emotionally charged.\",\"correctedText\":\"Social media's influence on politics is clear: while democratizing participation, it simultaneously intensifies polarization and emotional responses.\",\"explanation\": \"Use a semicolon after 'clear' to improve sentence structure. Remove redundancy by rephrasing for conciseness and clarity.\"},{\"id\":\"err-23\",\"type\":\"Grammar\",\"subType\":\"Subject-Verb Agreement\",\"incorrectText\":\"social media has become one of the most important parts of people's lives.\",\"correctedText\":\"Social media is a critical component in modern communication and information sharing.\",\"explanation\": \"Use more formal language to convey the point clearly. Remove redundancy by rephrasing for conciseness.\"},{\"id\":\"err-24\",\"type\":\"Grammar\",\"subType\":\"Passive Voice\",\"incorrectText\":\"social media has transformed political discourse in significant ways, making it more open and participatory but also more polarized and emotionally charged.\",\"correctedText\":\"Social media's influence on politics is evident as political discourse becomes both democratized in participation yet simultaneously amplified in polarization.\",\"explanation\": \"Use active voice where possible. Remove redundancy by rephrasing for conciseness and clarity.\"},{\"id\":\"err-25\",\"type\":\"Grammar\",\"subType\":\"Clause Agreement\",\"incorrectText\":\"social media has become one of the most important parts of people's lives.\",\"correctedText\":\"Social media, as a critical component in modern communication and information exchange, plays an increasingly significant role.\",\"explanation\": \"Use more formal language to convey the point clearly. Remove redundancy by rephrasing for conciseness and clarity.\"},{\"id\":\"err-26\",\"type\":\"Grammar\",\"subType\":\"Passive Voice\",\"incorrectText\":\"social media has transformed political discourse in significant ways, making it more open and participatory but also more polarized and emotionally charged.\",\"correctedText\":\"Social media's influence on politics is clear: while democratizing participation, it simultaneously amplifies polarization and emotional responses.\",\"explanation\": \"Use active voice where possible. Remove redundancy by rephrasing for conciseness and clarity.\"},{\"id\":\"err-27\",\"type\":\"Grammar\",\"subType\":\"Clause Agreement\",\"incorrectText\":\"social media has become one of the most important parts of people's lives.\",\"correctedText\":\"Social media, as a critical component in modern communication and information exchange, plays an increasingly significant role.\",\"explanation\": \"Use more formal language to convey the point clearly. Remove redundancy by rephrasing for conciseness and clarity.\"},{\"id\":\"err-28\",\"type\":\"Grammar\",\"subType\":\"Passive Voice\",\"incorrectText\":\"social media has become one of the most important parts of people's lives.\",\"correctedText\":\"Social media serves as a critical component in modern communication and information exchange.\",\"explanation\": \"Use more formal language to convey the point clearly. Remove redundancy by rephrasing for conciseness and clarity.\"}]\n}'''  # Your JSON string (as shown)

# Step 1: Extract all possible JSON-like objects from inside the "errorList" array
object_matches = re.findall(r'\{[^{}]+\}', raw_json)

valid_objects = []
for obj_str in object_matches:
    try:
        # Try parsing each object to ensure it's valid JSON
        parsed = json.loads(obj_str)
        required_keys = {"id", "start", "end", "type", "subType", "incorrectText", "correctedText", "explanation"}
        # Only keep the object if it has all required keys
        if required_keys.issubset(parsed.keys()):
            valid_objects.append(parsed)
    except json.JSONDecodeError:
        continue  # Skip invalid JSON fragments

# Step 2: Reconstruct a clean JSON
clean_json = {"errorList": valid_objects}

# Optional: pretty print
print(json.dumps(clean_json, indent=2,ensure_ascii=False))
