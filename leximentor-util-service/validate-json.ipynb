# %%
import json
import re

raw_json = '''{
  "errorList": [
    {
      "id": "err-1",
      "start": 13,
      "end": 15,
      "type": "Grammar",
      "subType": "Article",
      "incorrectText": "In",
      "correctedText": "It",
      "explanation": "The sentence requires a subject, not 'In'."
    },
    {
      "id": "err-2",
      "start": 25,
      "end": 28,
      "type": "Vocabulary",
      "subType": "Word Choice",
      "incorrectText": "one of the most important parts",
      "correctedText": "a key component",
      "explanation": "More formal and precise language is needed for a discussion of political discourse."
    },
    {
      "id": "err-3",
      "start": 35,
      "end": 39,
      "type": "Grammar",
      "subType": "Verb Form",
      "incorrectText": "has become",
      "correctedText": "has evolved",
      "explanation": "‘Evolved’ is a more appropriate term for describing the change in social media’s role."
    },
    {
      "id": "err-4",
      "start": 43,
      "end": 48,
      "type": "Vocabulary",
      "subType": "Precision",
      "incorrectText": "accessibility",
      "correctedText": "availability",
      "explanation": "'Accessibility' is too vague; 'availability' is more precise in this context."
    },
    {
      "id": "err-5",
      "start": 53,
      "end": 59,
      "type": "Grammar",
      "subType": "Verb Form",
      "incorrectText": "creates",
      "correctedText": "contributes to",
      "explanation": "‘Contributes to’ is a more nuanced and accurate description of the process."
    },
    {
      "id": "err-6",
      "start": 63,
      "end": 68,
      "type": "Vocabulary",
      "subType": "Word Choice",
      "incorrectText": "echo chambers",
      "correctedText": "filter bubbles",
      "explanation": "'Echo chambers' is a common term, but 'filter bubbles' is more descriptive of the algorithmic process."
    },
    {
      "id": "err-7",
      "start": 74,
      "end": 79,
      "type": "Grammar",
      "subType": "Verb Form",
      "incorrectText": "contributes to",
      "correctedText": "leads to",
      "explanation": "'Leads to' is a stronger and more direct way to express the cause-and-effect relationship."
    },
    {
      "id": "err-8",
      "start": 84,
      "end": 89,
      "type": "Vocabulary",
      "subType": "Word Choice",
      "incorrectText": "misinformation",
      "correctedText": "false narratives",
      "explanation": "'Misinformation' is a broad term; 'false narratives' is more specific and descriptive."
    },
    {
      "id": "err-9",
      "start": 96,
      "end": 99,
      "type": "Grammar",
      "subType": "Verb Form",
      "incorrectText": "share",
      "correctedText": "disseminate",
      "explanation": "'Disseminate' is a more formal and appropriate term for spreading information."
    },
    {
      "id": "err-10",
      "start": 104,
      "end": 109,
      "type": "Vocabulary",
      "subType": "Word Choice",
      "incorrectText": "harassment",
      "correctedText": "abuse",
      "explanation": "'Harassment' is too broad; 'abuse' is more specific to the context of online interactions."
    },
    {
      "id": "err-11",
      "start": 116,
      "end": 119,
      "type": "Vocabulary",
      "subType": "Word Choice",
      "incorrectText": "discourse",
      "correctedText": "debate",
      "explanation": "'Discourse' is too academic; 'debate' is more accessible and appropriate for this context."
    },
    {
      "id": "err-12",
      "start": 131,
      "end": 133,
      "type": "Vocabulary",
      "subType": "Word Choice",
      "incorrectText": "over",
      "correctedText": "excessive",
      "explanation": "'Over' is too vague; 'excessive' is more descriptive."
    },
    {
      "id": "err-13",
      "start": 146,
      "end": 149,
      "type": "Vocabulary",
      "subType": "Word Choice",
      "incorrectText": "discourse",
      "correctedText": "discussion",
      "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
    },
    {
      "id": "err-14",
      "start": 163,
      "end": 167,
      "type": "Vocabulary",
      "subType": "Word Choice",
      "incorrectText": "over",
      "correctedText": "excessive",
      "explanation": "'Over' is too vague; 'excessive' is more descriptive."
    },
    {
      "id": "err-15",
      "start": 173,
      "end": 177,
      "type": "Vocabulary",
      "subType": "Word Choice",
      "incorrectText": "discourse",
      "correctedText": "discussion",
      "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
    },
    {
      "id": "err-16",
      "start": 187,
      "end": 189,
      "type": "Vocabulary",
      "subType": "Word Choice",
      "incorrectText": "over",
      "correctedText": "excessive",
      "explanation": "'Over' is too vague; 'excessive' is more descriptive."
    },
    {
      "id": "err-17",
      "start": 197,
      "end": 201,
      "type": "Vocabulary",
      "subType": "Word Choice",
      "incorrectText": "discourse",
      "correctedText": "discussion",
      "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
    },
    {
      "id": "err-18",
      "start": 208,
      "end": 212,
      "type": "Vocabulary",
      "subType": "Word Choice",
      "incorrectText": "over",
      "correctedText": "excessive",
      "explanation": "'Over' is too vague; 'excessive' is more descriptive."
    },
    {
      "id": "err-19",
      "start": 218,
      "end": 221,
      "type": "Vocabulary",
      "subType": "Word Choice",
      "incorrectText": "discourse",
      "correctedText": "discussion",
      "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
    },
    {
      "id": "err-20",
      "start": 227,
      "end": 231,
      "type": "Vocabulary",
      "subType": "Word Choice",
      "incorrectText": "over",
      "correctedText": "excessive",
      "explanation": "'Over' is too vague; 'excessive' is more descriptive."
    },
    {
      "id": "err-21",
      "start": 233,
      "end": 237,
      "type": "Vocabulary",
      "subType": "Word Choice",
      "incorrectText": "discourse",
      "correctedText": "discussion",
      "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
    },
    {
      "id": "err-22",
      "start": 243,
      "end": 247,
      "type": "Vocabulary",
      "subType": "Word Choice",
      "incorrectText": "over",
      "correctedText": "excessive",
      "explanation": "'Over' is too vague; 'excessive' is more descriptive."
    },
    {
      "id": "err-23",
      "start": 253,
      "end": 257,
      "type": "Vocabulary",
      "subType": "Word Choice",
      "incorrectText": "discourse",
      "correctedText": "discussion",
      "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
    },
    {
      "id": "err-24",
      "start": 263,
      "end": 267,
      "type": "Vocabulary",
      "subType": "Word Choice",
      "incorrectText": "discourse",
      "correctedText": "discussion",
      "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
    },
    {
      "id": "err-25",
      "start": 273,
      "end": 277,
      "type": "Vocabulary",
      "subType": "Word Choice",
      "incorrectText": "over",
      "correctedText": "excessive",
      "explanation": "'Over' is too vague; 'excessive' is more descriptive."
    },
    {
      "id": "err-26",
      "start": 283,
      "end": 287,
      "type": "Vocabulary",
      "subType": "Word Choice",
      "incorrectText": "discourse",
      "correctedText": "discussion",
      "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
    },
    {
      "id": "err-27",
      "start": 293,
      "end": 297,
      "type": "Vocabulary",
      "subType": "Word Choice",
      "incorrectText": "over",
      "correctedText": "excessive",
      "explanation": "'Over' is too vague; 'excessive' is more descriptive."
    },
    {
      "id": "err-28",
      "start": 303,
      "end": 307,
      "type": "Vocabulary",
      "subType": "Word Choice",
      "incorrectText": "discourse",
      "correctedText": "discussion",
      "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
    },
    {
      "id": "err-29",
      "start": 313,
      "end": 317,
      "type": "Vocabulary",
      "subType": "Word Choice",
      "incorrectText": "over",
      "correctedText": "excessive",
      "explanation": "'Over' is too vague; 'excessive' is more descriptive."
    },
    {
      "id": "err-30",
      "start": 317,
      "end": 321,
      "type": "Vocabulary",
      "subType": "Word Choice",
      "incorrectText": "discourse",
      "correctedText": "discussion",
      "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
    }
  ]
}'''  # Your JSON string (as shown)

# Step 1: Extract all possible JSON-like objects from inside the "errorList" array
object_matches = re.findall(r'\{[^{}]+\}', raw_json)

valid_objects = []
for obj_str in object_matches:
    try:
        # Try parsing each object to ensure it's valid JSON
        parsed = json.loads(obj_str)
        required_keys = {"id", "type", "subType", "incorrectText", "correctedText", "explanation"}
        # Only keep the object if it has all required keys
        if required_keys.issubset(parsed.keys()):
            valid_objects.append(parsed)
    except json.JSONDecodeError:
        continue  # Skip invalid JSON fragments

# Step 2: Reconstruct a clean JSON
clean_json = {"errorList": valid_objects}

# Optional: pretty print
print(json.dumps(clean_json, indent=2,ensure_ascii=False))
# Out:
# {
#   "errorList": [
#     {
#       "id": "err-1",
#       "start": 13,
#       "end": 15,
#       "type": "Grammar",
#       "subType": "Article",
#       "incorrectText": "In",
#       "correctedText": "It",
#       "explanation": "The sentence requires a subject, not 'In'."
#     },
#     {
#       "id": "err-2",
#       "start": 25,
#       "end": 28,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "one of the most important parts",
#       "correctedText": "a key component",
#       "explanation": "More formal and precise language is needed for a discussion of political discourse."
#     },
#     {
#       "id": "err-3",
#       "start": 35,
#       "end": 39,
#       "type": "Grammar",
#       "subType": "Verb Form",
#       "incorrectText": "has become",
#       "correctedText": "has evolved",
#       "explanation": "‘Evolved’ is a more appropriate term for describing the change in social media’s role."
#     },
#     {
#       "id": "err-4",
#       "start": 43,
#       "end": 48,
#       "type": "Vocabulary",
#       "subType": "Precision",
#       "incorrectText": "accessibility",
#       "correctedText": "availability",
#       "explanation": "'Accessibility' is too vague; 'availability' is more precise in this context."
#     },
#     {
#       "id": "err-5",
#       "start": 53,
#       "end": 59,
#       "type": "Grammar",
#       "subType": "Verb Form",
#       "incorrectText": "creates",
#       "correctedText": "contributes to",
#       "explanation": "‘Contributes to’ is a more nuanced and accurate description of the process."
#     },
#     {
#       "id": "err-6",
#       "start": 63,
#       "end": 68,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "echo chambers",
#       "correctedText": "filter bubbles",
#       "explanation": "'Echo chambers' is a common term, but 'filter bubbles' is more descriptive of the algorithmic process."
#     },
#     {
#       "id": "err-7",
#       "start": 74,
#       "end": 79,
#       "type": "Grammar",
#       "subType": "Verb Form",
#       "incorrectText": "contributes to",
#       "correctedText": "leads to",
#       "explanation": "'Leads to' is a stronger and more direct way to express the cause-and-effect relationship."
#     },
#     {
#       "id": "err-8",
#       "start": 84,
#       "end": 89,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "misinformation",
#       "correctedText": "false narratives",
#       "explanation": "'Misinformation' is a broad term; 'false narratives' is more specific and descriptive."
#     },
#     {
#       "id": "err-9",
#       "start": 96,
#       "end": 99,
#       "type": "Grammar",
#       "subType": "Verb Form",
#       "incorrectText": "share",
#       "correctedText": "disseminate",
#       "explanation": "'Disseminate' is a more formal and appropriate term for spreading information."
#     },
#     {
#       "id": "err-10",
#       "start": 104,
#       "end": 109,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "harassment",
#       "correctedText": "abuse",
#       "explanation": "'Harassment' is too broad; 'abuse' is more specific to the context of online interactions."
#     },
#     {
#       "id": "err-11",
#       "start": 116,
#       "end": 119,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "debate",
#       "explanation": "'Discourse' is too academic; 'debate' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-12",
#       "start": 131,
#       "end": 133,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-13",
#       "start": 146,
#       "end": 149,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-14",
#       "start": 163,
#       "end": 167,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-15",
#       "start": 173,
#       "end": 177,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-16",
#       "start": 187,
#       "end": 189,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-17",
#       "start": 197,
#       "end": 201,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-18",
#       "start": 208,
#       "end": 212,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-19",
#       "start": 218,
#       "end": 221,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-20",
#       "start": 227,
#       "end": 231,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-21",
#       "start": 233,
#       "end": 237,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-22",
#       "start": 243,
#       "end": 247,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-23",
#       "start": 253,
#       "end": 257,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-24",
#       "start": 263,
#       "end": 267,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-25",
#       "start": 273,
#       "end": 277,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-26",
#       "start": 283,
#       "end": 287,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-27",
#       "start": 293,
#       "end": 297,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-28",
#       "start": 303,
#       "end": 307,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-29",
#       "start": 313,
#       "end": 317,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-30",
#       "start": 317,
#       "end": 321,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     }
#   ]
# }

# %%
### 1. Add start and end to the object.

# %%
for error in clean_json["errorList"]:
    error["start"] = -1
    error["end"] = -1

# Print updated JSON
print(json.dumps(clean_json, indent=2))
# Out:
# {
#   "errorList": [
#     {
#       "id": "err-1",
#       "start": -1,
#       "end": -1,
#       "type": "Grammar",
#       "subType": "Article",
#       "incorrectText": "In",
#       "correctedText": "It",
#       "explanation": "The sentence requires a subject, not 'In'."
#     },
#     {
#       "id": "err-2",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "one of the most important parts",
#       "correctedText": "a key component",
#       "explanation": "More formal and precise language is needed for a discussion of political discourse."
#     },
#     {
#       "id": "err-3",
#       "start": -1,
#       "end": -1,
#       "type": "Grammar",
#       "subType": "Verb Form",
#       "incorrectText": "has become",
#       "correctedText": "has evolved",
#       "explanation": "\u2018Evolved\u2019 is a more appropriate term for describing the change in social media\u2019s role."
#     },
#     {
#       "id": "err-4",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Precision",
#       "incorrectText": "accessibility",
#       "correctedText": "availability",
#       "explanation": "'Accessibility' is too vague; 'availability' is more precise in this context."
#     },
#     {
#       "id": "err-5",
#       "start": -1,
#       "end": -1,
#       "type": "Grammar",
#       "subType": "Verb Form",
#       "incorrectText": "creates",
#       "correctedText": "contributes to",
#       "explanation": "\u2018Contributes to\u2019 is a more nuanced and accurate description of the process."
#     },
#     {
#       "id": "err-6",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "echo chambers",
#       "correctedText": "filter bubbles",
#       "explanation": "'Echo chambers' is a common term, but 'filter bubbles' is more descriptive of the algorithmic process."
#     },
#     {
#       "id": "err-7",
#       "start": -1,
#       "end": -1,
#       "type": "Grammar",
#       "subType": "Verb Form",
#       "incorrectText": "contributes to",
#       "correctedText": "leads to",
#       "explanation": "'Leads to' is a stronger and more direct way to express the cause-and-effect relationship."
#     },
#     {
#       "id": "err-8",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "misinformation",
#       "correctedText": "false narratives",
#       "explanation": "'Misinformation' is a broad term; 'false narratives' is more specific and descriptive."
#     },
#     {
#       "id": "err-9",
#       "start": -1,
#       "end": -1,
#       "type": "Grammar",
#       "subType": "Verb Form",
#       "incorrectText": "share",
#       "correctedText": "disseminate",
#       "explanation": "'Disseminate' is a more formal and appropriate term for spreading information."
#     },
#     {
#       "id": "err-10",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "harassment",
#       "correctedText": "abuse",
#       "explanation": "'Harassment' is too broad; 'abuse' is more specific to the context of online interactions."
#     },
#     {
#       "id": "err-11",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "debate",
#       "explanation": "'Discourse' is too academic; 'debate' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-12",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-13",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-14",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-15",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-16",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-17",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-18",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-19",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-20",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-21",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-22",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-23",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-24",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-25",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-26",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-27",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-28",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-29",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-30",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     }
#   ]
# }

# %% [markdown]
# # Update start and end index.

# %%
import json
import re
from difflib import SequenceMatcher

# Function to tokenize a string into words
def tokenize(text):
    return re.findall(r"\b\w[\w'-]*\b", text)

# Function to compute similarity between two token lists
def similarity(a, b):
    return SequenceMatcher(None, a, b).ratio()

# Load the essay
essay = """In today's modern society, social media has become one of the most important parts of people's lives. Its role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs. With the rise of platforms like Twitter, Facebook, and Instagram, political discourse is no longer limited to leaders or experts—everyone can now participate. While this shift has brought some benefits, it has also created several problems in how people discuss and understand politics. First of all, social media has made it very easy for everyone to share their opinions. Before its rise, people relied on newspapers or television to learn about political events. Now, anyone can post an opinion or share a news article without verifying its accuracy. This accessibility has increased political engagement, but it has also raised the risk of misinformation spreading rapidly. Sometimes, a tweet or post goes viral within minutes—even if it’s completely false. This can heavily influence public opinion and decision-making. Another significant issue is the creation of *echo chambers*. This occurs when a person only sees posts, videos, or information that align with their existing beliefs. Most social media platforms use algorithms that show users content based on their past behavior. So, if someone supports a particular political party, they’re more likely to see content that reinforces their views and less of the opposing side. As a result, people may start believing their perspective is the only correct one, which makes political conversations more hostile and less open-minded. The rise of fake news and misinformation is also a serious concern. Political groups or malicious actors can easily create and spread false stories online. Many users don’t verify facts before sharing a post—they believe it because it matches their opinion or was shared by someone they trust. During elections, this becomes especially dangerous, as fake news can influence how people vote or view a candidate. Several recent elections around the world have shown the harmful effects of misinformation. Social media also enables the spread of online harassment. Political leaders, journalists, and even ordinary people often face abusive comments or threats for sharing opinions that others disagree with. This kind of hostile environment can discourage individuals from expressing their views. In a healthy democracy, people should feel safe discussing politics without fear of backlash or intimidation. However, it's not all negative. Social media has also played a major role in raising awareness about important political issues. Movements like #BlackLivesMatter and global climate change protests gained widespread attention and support thanks to social media platforms. People across the world can now connect with and support causes in other countries. It has amplified voices that were previously unheard, and has especially encouraged younger generations to become more politically active and vocal. In some cases, political leaders use social media to communicate directly with the public. This removes the traditional gatekeepers like news channels and allows leaders to explain policies, share updates, or respond to citizens. This can increase transparency and accessibility. However, it also depends on how responsibly leaders use these platforms. If used to spread hate or false information, the impact can be harmful. Another downside is the oversimplification of complex ideas. Political discussions require depth, evidence, and thoughtful reflection. But social media often favors short posts—like a 280-character tweet—which can make debates shallow. Many users focus on "winning" arguments instead of trying to understand other viewpoints. Finally, social media has influenced how news is produced and shared. Many news outlets now prioritize content that gets more likes and shares, sometimes at the expense of accuracy. Sensational headlines and clickbait have become common. This turns political coverage into entertainment and shifts attention away from serious issues. In conclusion, social media has transformed political discourse in significant ways. It has made political conversations more open and participatory, but also more polarized and emotionally charged. Challenges like fake news, echo chambers, online abuse, and shallow debates must be addressed. At the same time, the ability to raise awareness and include diverse voices is a powerful benefit. Moving forward, we must use social media responsibly—through education, critical thinking, fact-checking, and respectful dialogue—to ensure that its impact on politics is more positive than negative."""
words = tokenize(essay)

# Load the data (replace with actual JSON if needed)
data = clean_json

# Main logic: Try to match incorrectText to essay with fuzzy logic
for err in data["errorList"]:
    phrase = err["incorrectText"]
    phrase_tokens = tokenize(phrase)

    best_match = {"score": 0.0, "start": -1, "end": -1}
    
    for i in range(len(words) - len(phrase_tokens) + 1):
        window = words[i:i + len(phrase_tokens)]
        score = similarity(window, phrase_tokens)
        
        if score > best_match["score"]:
            best_match = {"score": score, "start": i, "end": i + len(phrase_tokens)}

    # Accept match if score is good enough
    if best_match["score"] > 0.6:  # Adjust threshold for tolerance
        err["start"] = best_match["start"]
        err["end"] = best_match["end"]
    else:
        print(f"⚠️ Not found (low similarity): '{phrase}'")
        err["start"] = -1
        err["end"] = -1

# Output results
print(json.dumps(data, indent=2, ensure_ascii=False))

# %%
import json
import re

def tokenize_words(text):
    return list(re.finditer(r"\b\w[\w'-]*\b", text))

def find_error_indices(essay, error_list):
    word_matches = tokenize_words(essay)
    word_boundaries = [(m.start(), m.end()) for m in word_matches]

    for err in error_list:
        phrase = err["incorrectText"]
        norm_essay = essay
        norm_phrase = phrase.strip()

        # Try to find the phrase in essay
        idx = norm_essay.find(norm_phrase)
        if idx == -1:
            err["start"] = -1
            err["end"] = -1
            print(f"❌ Not found: {err['id']} — {norm_phrase[:60]}...")
            continue

        # Count how many word tokens come before idx
        start_index = sum(1 for (start, _) in word_boundaries if start < idx)
        end_pos = idx + len(norm_phrase)
        end_index = sum(1 for (start, end) in word_boundaries if start < end_pos)

        err["start"] = start_index
        err["end"] = end_index

    return error_list



# Load your essay
essay = """In today's modern society, social media has become one of the most important parts of people's lives. Its role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs. With the rise of platforms like Twitter, Facebook, and Instagram, political discourse is no longer limited to leaders or experts—everyone can now participate. While this shift has brought some benefits, it has also created several problems in how people discuss and understand politics. First of all, social media has made it very easy for everyone to share their opinions. Before its rise, people relied on newspapers or television to learn about political events. Now, anyone can post an opinion or share a news article without verifying its accuracy. This accessibility has increased political engagement, but it has also raised the risk of misinformation spreading rapidly. Sometimes, a tweet or post goes viral within minutes—even if it’s completely false. This can heavily influence public opinion and decision-making. Another significant issue is the creation of *echo chambers*. This occurs when a person only sees posts, videos, or information that align with their existing beliefs. Most social media platforms use algorithms that show users content based on their past behavior. So, if someone supports a particular political party, they’re more likely to see content that reinforces their views and less of the opposing side. As a result, people may start believing their perspective is the only correct one, which makes political conversations more hostile and less open-minded. The rise of fake news and misinformation is also a serious concern. Political groups or malicious actors can easily create and spread false stories online. Many users don’t verify facts before sharing a post—they believe it because it matches their opinion or was shared by someone they trust. During elections, this becomes especially dangerous, as fake news can influence how people vote or view a candidate. Several recent elections around the world have shown the harmful effects of misinformation. Social media also enables the spread of online harassment. Political leaders, journalists, and even ordinary people often face abusive comments or threats for sharing opinions that others disagree with. This kind of hostile environment can discourage individuals from expressing their views. In a healthy democracy, people should feel safe discussing politics without fear of backlash or intimidation. However, it's not all negative. Social media has also played a major role in raising awareness about important political issues. Movements like #BlackLivesMatter and global climate change protests gained widespread attention and support thanks to social media platforms. People across the world can now connect with and support causes in other countries. It has amplified voices that were previously unheard, and has especially encouraged younger generations to become more politically active and vocal. In some cases, political leaders use social media to communicate directly with the public. This removes the traditional gatekeepers like news channels and allows leaders to explain policies, share updates, or respond to citizens. This can increase transparency and accessibility. However, it also depends on how responsibly leaders use these platforms. If used to spread hate or false information, the impact can be harmful. Another downside is the oversimplification of complex ideas. Political discussions require depth, evidence, and thoughtful reflection. But social media often favors short posts—like a 280-character tweet—which can make debates shallow. Many users focus on "winning" arguments instead of trying to understand other viewpoints. Finally, social media has influenced how news is produced and shared. Many news outlets now prioritize content that gets more likes and shares, sometimes at the expense of accuracy. Sensational headlines and clickbait have become common. This turns political coverage into entertainment and shifts attention away from serious issues. In conclusion, social media has transformed political discourse in significant ways. It has made political conversations more open and participatory, but also more polarized and emotionally charged. Challenges like fake news, echo chambers, online abuse, and shallow debates must be addressed. At the same time, the ability to raise awareness and include diverse voices is a powerful benefit. Moving forward, we must use social media responsibly—through education, critical thinking, fact-checking, and respectful dialogue—to ensure that its impact on politics is more positive than negative."""

# Load your errorList (as dict)
data=clean_json

# Run matching
updated_errors = find_error_indices(essay, data["errorList"])

# Check what we matched
for err in updated_errors:
    if err["start"] == -1:
        continue
    print(f"{err['id']} — [{err['start']}:{err['end']}] — {err['incorrectText']}")
# Out:
# ❌ Not found: err-4 — 's role has evolved from simply being a communication tool t...
# ❌ Not found: err-5 — 's role has evolved from simply being a communication tool t...
# ❌ Not found: err-6 — 's role has evolved from simply being a communication tool t...
# ❌ Not found: err-7 — 's role has evolved from simply being a communication tool t...
# ❌ Not found: err-8 — 's role has evolved from simply being a communication tool t...
# ❌ Not found: err-9 — 's role has evolved from simply being a communication tool t...
# ❌ Not found: err-10 — 's role has evolved from simply being a communication tool t...
# ❌ Not found: err-11 — 's role has evolved from simply being a communication tool t...
# ❌ Not found: err-12 — 's role has evolved from simply being a communication tool t...
# ❌ Not found: err-13 — 's role has evolved from simply being a communication tool t...
# ❌ Not found: err-14 — 's role has evolved from simply being a communication tool t...
# ❌ Not found: err-15 — 's role has evolved from simply being a communication tool t...
# ❌ Not found: err-17 — 's role has evolved from simply being a communication tool t...
# ❌ Not found: err-18 — 's role has evolved from simply being a communication tool t...
# ❌ Not found: err-21 — 's role has evolved from simply being a communication tool t...
# ❌ Not found: err-22 — 's role has evolved from simply being a communication tool t...
# ❌ Not found: err-23 — 's role has evolved from simply being a communication tool t...
# ❌ Not found: err-24 — 's role has evolved from simply being a communication tool t...
# ❌ Not found: err-25 — 's role has evolved from simply being a communication tool t...
# ❌ Not found: err-26 — 's role has evolved from simply being a communication tool t...
# ❌ Not found: err-27 — 's role has evolved from simply being a communication tool t...
# ❌ Not found: err-28 — 's role has evolved from simply being a communication tool t...
# ❌ Not found: err-29 — 's role has evolved from simply being a communication tool t...
# ❌ Not found: err-30 — 's role has evolved from simply being a communication tool t...
# err-1 — [0:17] — In today's modern society, social media has become one of the most important parts of people's lives.
# err-2 — [17:38] — Its role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs.
# err-3 — [48:62] — , political discourse is no longer limited to leaders or experts—everyone can now participate.
# err-16 — [48:62] — , political discourse is no longer limited to leaders or experts—everyone can now participate.
# err-19 — [48:62] — , political discourse is no longer limited to leaders or experts—everyone can now participate.
# err-20 — [48:62] — , political discourse is no longer limited to leaders or experts—everyone can now participate.

# %% [markdown]
# ## Vaidate if done correctly

# %%
JSON_STR='''
In today's modern society, social media has become one of the most important parts of people's lives. Its role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs. With the rise of platforms like Twitter, Facebook, and Instagram, political discourse is no longer limited to leaders or experts—everyone can now participate. While this shift has brought some benefits, it has also created several problems in how people discuss and understand politics. First of all, social media has made it very easy for everyone to share their opinions. Before its rise, people relied on newspapers or television to learn about political events. Now, anyone can post an opinion or share a news article without verifying its accuracy. This accessibility has increased political engagement, but it has also raised the risk of misinformation spreading rapidly. Sometimes, a tweet or post goes viral within minutes—even if it’s completely false. This can heavily influence public opinion and decision-making. Another significant issue is the creation of *echo chambers*. This occurs when a person only sees posts, videos, or information that align with their existing beliefs. Most social media platforms use algorithms that show users content based on their past behavior. So, if someone supports a particular political party, they’re more likely to see content that reinforces their views and less of the opposing side. As a result, people may start believing their perspective is the only correct one, which makes political conversations more hostile and less open-minded. The rise of fake news and misinformation is also a serious concern. Political groups or malicious actors can easily create and spread false stories online. Many users don’t verify facts before sharing a post—they believe it because it matches their opinion or was shared by someone they trust. During elections, this becomes especially dangerous, as fake news can influence how people vote or view a candidate. Several recent elections around the world have shown the harmful effects of misinformation. Social media also enables the spread of online harassment. Political leaders, journalists, and even ordinary people often face abusive comments or threats for sharing opinions that others disagree with. This kind of hostile environment can discourage individuals from expressing their views. In a healthy democracy, people should feel safe discussing politics without fear of backlash or intimidation. However, it's not all negative. Social media has also played a major role in raising awareness about important political issues. Movements like #BlackLivesMatter and global climate change protests gained widespread attention and support thanks to social media platforms. People across the world can now connect with and support causes in other countries. It has amplified voices that were previously unheard, and has especially encouraged younger generations to become more politically active and vocal. In some cases, political leaders use social media to communicate directly with the public. This removes the traditional gatekeepers like news channels and allows leaders to explain policies, share updates, or respond to citizens. This can increase transparency and accessibility. However, it also depends on how responsibly leaders use these platforms. If used to spread hate or false information, the impact can be harmful. Another downside is the oversimplification of complex ideas. Political discussions require depth, evidence, and thoughtful reflection. But social media often favors short posts—like a 280-character tweet—which can make debates shallow. Many users focus on "winning" arguments instead of trying to understand other viewpoints. Finally, social media has influenced how news is produced and shared. Many news outlets now prioritize content that gets more likes and shares, sometimes at the expense of accuracy. Sensational headlines and clickbait have become common. This turns political coverage into entertainment and shifts attention away from serious issues. In conclusion, social media has transformed political discourse in significant ways. It has made political conversations more open and participatory, but also more polarized and emotionally charged. Challenges like fake news, echo chambers, online abuse, and shallow debates must be addressed. At the same time, the ability to raise awareness and include diverse voices is a powerful benefit. Moving forward, we must use social media responsibly—through education, critical thinking, fact-checking, and respectful dialogue—to ensure that its impact on politics is more positive than negative.
'''

# %%
for json_item in data["errorList"]:
    start=json_item['start']
    end=json_item['end']
    print(f"{json_item['id']}-----incorrectText={json_item['incorrectText']}-----tagged={JSON_STR[start:end]}")
# Out:
# err-1-----incorrectText=In today's modern society, social media has become one of the most important parts of people's lives.-----tagged=
# In today's moder
# err-2-----incorrectText=Its role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs.-----tagged=n society, social med
# err-3-----incorrectText=, political discourse is no longer limited to leaders or experts—everyone can now participate.-----tagged=ome one of the
# err-4-----incorrectText='s role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs.-----tagged=n society, social med
# err-5-----incorrectText='s role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs.-----tagged=n society, social med
# err-6-----incorrectText='s role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs.-----tagged=n society, social med
# err-7-----incorrectText='s role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs.-----tagged=n society, social med
# err-8-----incorrectText='s role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs.-----tagged=n society, social med
# err-9-----incorrectText='s role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs.-----tagged=n society, social med
# err-10-----incorrectText='s role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs.-----tagged=n society, social med
# err-11-----incorrectText='s role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs.-----tagged=n society, social med
# err-12-----incorrectText='s role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs.-----tagged=n society, social med
# err-13-----incorrectText='s role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs.-----tagged=n society, social med
# err-14-----incorrectText='s role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs.-----tagged=n society, social med
# err-15-----incorrectText='s role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs.-----tagged=n society, social med
# err-16-----incorrectText=, political discourse is no longer limited to leaders or experts—everyone can now participate.-----tagged=ome one of the
# err-17-----incorrectText='s role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs.-----tagged=n society, social med
# err-18-----incorrectText='s role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs.-----tagged=n society, social med
# err-19-----incorrectText=, political discourse is no longer limited to leaders or experts—everyone can now participate.-----tagged=ome one of the
# err-20-----incorrectText=, political discourse is no longer limited to leaders or experts—everyone can now participate.-----tagged=ome one of the
# err-21-----incorrectText='s role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs.-----tagged=n society, social med
# err-22-----incorrectText='s role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs.-----tagged=n society, social med
# err-23-----incorrectText='s role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs.-----tagged=n society, social med
# err-24-----incorrectText='s role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs.-----tagged=n society, social med
# err-25-----incorrectText='s role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs.-----tagged=n society, social med
# err-26-----incorrectText='s role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs.-----tagged=n society, social med
# err-27-----incorrectText='s role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs.-----tagged=n society, social med
# err-28-----incorrectText='s role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs.-----tagged=n society, social med
# err-29-----incorrectText='s role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs.-----tagged=n society, social med
# err-30-----incorrectText='s role has evolved from simply being a communication tool to a platform for sharing opinions, news, and even political beliefs.-----tagged=n society, social med

# %%
import json
import re

def find_text_positions(json_str, error_list):
    # Track visited positions to handle duplicates
    visited_positions = []
    
    # Process each error in the errorList
    for error in error_list:
        incorrect_text = error['incorrectText']
        # Escape special characters in incorrect_text for regex
        escaped_text = re.escape(incorrect_text)
        
        # Find all matches of incorrect_text in json_str
        matches = [(m.start(), m.end()) for m in re.finditer(escaped_text, json_str)]
        
        # Filter out already visited matches
        for start, end in matches:
            if start not in visited_positions:
                error['start'] = start
                error['end'] = end
                visited_positions.append(start)
                break
        else:
            # If no unvisited match is found, keep start and end as -1
            error['start'] = -1
            error['end'] = -1
    
    return error_list

# Input JSON string and error list
json_str = JSON_STR

error_list =clean_json["errorList"]

# Update positions
updated_error_list = find_text_positions(json_str, error_list)

# Output the updated JSON
updated_json = {"errorList": updated_error_list}
print(json.dumps(updated_json, indent=2,ensure_ascii=False))
# Out:
# {
#   "errorList": [
#     {
#       "id": "err-1",
#       "start": 1,
#       "end": 3,
#       "type": "Grammar",
#       "subType": "Article",
#       "incorrectText": "In",
#       "correctedText": "It",
#       "explanation": "The sentence requires a subject, not 'In'."
#     },
#     {
#       "id": "err-2",
#       "start": 52,
#       "end": 83,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "one of the most important parts",
#       "correctedText": "a key component",
#       "explanation": "More formal and precise language is needed for a discussion of political discourse."
#     },
#     {
#       "id": "err-3",
#       "start": 41,
#       "end": 51,
#       "type": "Grammar",
#       "subType": "Verb Form",
#       "incorrectText": "has become",
#       "correctedText": "has evolved",
#       "explanation": "‘Evolved’ is a more appropriate term for describing the change in social media’s role."
#     },
#     {
#       "id": "err-4",
#       "start": 792,
#       "end": 805,
#       "type": "Vocabulary",
#       "subType": "Precision",
#       "incorrectText": "accessibility",
#       "correctedText": "availability",
#       "explanation": "'Accessibility' is too vague; 'availability' is more precise in this context."
#     },
#     {
#       "id": "err-5",
#       "start": -1,
#       "end": -1,
#       "type": "Grammar",
#       "subType": "Verb Form",
#       "incorrectText": "creates",
#       "correctedText": "contributes to",
#       "explanation": "‘Contributes to’ is a more nuanced and accurate description of the process."
#     },
#     {
#       "id": "err-6",
#       "start": 1104,
#       "end": 1117,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "echo chambers",
#       "correctedText": "filter bubbles",
#       "explanation": "'Echo chambers' is a common term, but 'filter bubbles' is more descriptive of the algorithmic process."
#     },
#     {
#       "id": "err-7",
#       "start": -1,
#       "end": -1,
#       "type": "Grammar",
#       "subType": "Verb Form",
#       "incorrectText": "contributes to",
#       "correctedText": "leads to",
#       "explanation": "'Leads to' is a stronger and more direct way to express the cause-and-effect relationship."
#     },
#     {
#       "id": "err-8",
#       "start": 877,
#       "end": 891,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "misinformation",
#       "correctedText": "false narratives",
#       "explanation": "'Misinformation' is a broad term; 'false narratives' is more specific and descriptive."
#     },
#     {
#       "id": "err-9",
#       "start": 585,
#       "end": 590,
#       "type": "Grammar",
#       "subType": "Verb Form",
#       "incorrectText": "share",
#       "correctedText": "disseminate",
#       "explanation": "'Disseminate' is a more formal and appropriate term for spreading information."
#     },
#     {
#       "id": "err-10",
#       "start": 2175,
#       "end": 2185,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "harassment",
#       "correctedText": "abuse",
#       "explanation": "'Harassment' is too broad; 'abuse' is more specific to the context of online interactions."
#     },
#     {
#       "id": "err-11",
#       "start": 309,
#       "end": 318,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "debate",
#       "explanation": "'Discourse' is too academic; 'debate' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-12",
#       "start": 3483,
#       "end": 3487,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-13",
#       "start": 4173,
#       "end": 4182,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-14",
#       "start": 4045,
#       "end": 4049,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-15",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-16",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-17",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-18",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-19",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-20",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-21",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-22",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-23",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-24",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-25",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-26",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-27",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-28",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     },
#     {
#       "id": "err-29",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "over",
#       "correctedText": "excessive",
#       "explanation": "'Over' is too vague; 'excessive' is more descriptive."
#     },
#     {
#       "id": "err-30",
#       "start": -1,
#       "end": -1,
#       "type": "Vocabulary",
#       "subType": "Word Choice",
#       "incorrectText": "discourse",
#       "correctedText": "discussion",
#       "explanation": "'Discourse' is too academic; 'discussion' is more accessible and appropriate for this context."
#     }
#   ]
# }

# %%
for json_item in updated_json["errorList"]:
    start=json_item['start']
    end=json_item['end']
    print(f"{json_item['id']}-----incorrectText={json_item['incorrectText']}-----tagged={JSON_STR[start:end]}")
# Out:
# err-1-----incorrectText=In-----tagged=In
# err-2-----incorrectText=one of the most important parts-----tagged=one of the most important parts
# err-3-----incorrectText=has become-----tagged=has become
# err-4-----incorrectText=accessibility-----tagged=accessibility
# err-5-----incorrectText=creates-----tagged=
# err-6-----incorrectText=echo chambers-----tagged=echo chambers
# err-7-----incorrectText=contributes to-----tagged=
# err-8-----incorrectText=misinformation-----tagged=misinformation
# err-9-----incorrectText=share-----tagged=share
# err-10-----incorrectText=harassment-----tagged=harassment
# err-11-----incorrectText=discourse-----tagged=discourse
# err-12-----incorrectText=over-----tagged=over
# err-13-----incorrectText=discourse-----tagged=discourse
# err-14-----incorrectText=over-----tagged=over
# err-15-----incorrectText=discourse-----tagged=
# err-16-----incorrectText=over-----tagged=
# err-17-----incorrectText=discourse-----tagged=
# err-18-----incorrectText=over-----tagged=
# err-19-----incorrectText=discourse-----tagged=
# err-20-----incorrectText=over-----tagged=
# err-21-----incorrectText=discourse-----tagged=
# err-22-----incorrectText=over-----tagged=
# err-23-----incorrectText=discourse-----tagged=
# err-24-----incorrectText=discourse-----tagged=
# err-25-----incorrectText=over-----tagged=
# err-26-----incorrectText=discourse-----tagged=
# err-27-----incorrectText=over-----tagged=
# err-28-----incorrectText=discourse-----tagged=
# err-29-----incorrectText=over-----tagged=
# err-30-----incorrectText=discourse-----tagged=
